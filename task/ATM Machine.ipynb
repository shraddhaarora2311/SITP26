# %%
bal_pin=int(input("enter the pin number:-"))
balance=int(input("enter the balance amount:-"))
if _bal_pin==45678:
    if balance>=6000:  
        print("Enter a balance amount:-1.Deposit,2.Withdraw,3.Check Balance")
    else:
        print("Invalid pin number")

# %%
class BankFunction:
    balance = 0
    def deposit(self):
        amount=int(input("enter the amount:-"))
        self.balance = self.balance + amount
        print("Total Balance:", self.balance)

    def withdraw(self):
        amount = int(input("Enter Withdraw Amount: "))

        if amount <= self.balance:
            self.balance = self.balance - amount
            print("Remaining Balance:", self.balance)

        else:
            print("Insufficient Balance")

    def check_balance(self):
        print("Current Balance:", self.balance)
obj = BankFunction()
obj.deposit()
obj.withdraw()
obj.check_balance()
# Out:
# Total Balance: 5000
# Remaining Balance: 4300
# Current Balance: 4300

# %%
class bmi_calculator:
    def __init__(self , height , weight):
        self.height = height
        self.weight = weight
        self.calculator()
            
    def calculator(self):
        bmi = self.weight/(self.height*self.height)
        print("BMI : ", bmi)

person1 = bmi_calculator(1.75 , 70)
# Out:
# BMI :  22.857142857142858

# %%
pin = int(input("Enter PIN: "))
balance = 5000

if pin == 45678:
    amount = int(input("Enter Withdraw Amount: "))
    
    if amount <= balance:
        balance = balance - amount
        print("Remaining Balance =", balance)
    else:
        print("Insufficient Balance")
else:
    print("Invalid PIN")
# Out:
# Remaining Balance = 500

# %%
bal_pin = int(input("Enter PIN Number: "))
balance = int(input("Enter Balance Amount: "))

if bal_pin == 45678:
    
    amount = int(input("Enter Deposit Amount: "))
    balance = balance + amount
    print("Updated Balance =", balance)

else:
    print("Invalid PIN Number")
# Out:
# Updated Balance = 9000

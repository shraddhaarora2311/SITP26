# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\data science\pandas\Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  str
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  str
# dtypes: float64(4), str(4)
# memory usage: 2.0 MB

# %%
df[['brand']]
# Out:
#                brand
# 0                TVS
# 1      Royal Enfield
# 2            Triumph
# 3                TVS
# 4             Yamaha
# ...              ...
# 32643           Hero
# 32644            TVS
# 32645          Bajaj
# 32646           Hero
# 32647          Bajaj
#
# [32648 rows x 1 columns]

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()# duplicate value ke count ke liye use hota h
# Out:
# np.int64(25324)

# %%
df.isnull()
# Out:
#        bike_name  price   city  kms_driven  owner    age  power  brand
# 0          False  False  False       False  False  False  False  False
# 1          False  False  False       False  False  False  False  False
# 2          False  False  False       False  False  False  False  False
# 3          False  False  False       False  False  False  False  False
# 4          False  False  False       False  False  False  False  False
# ...          ...    ...    ...         ...    ...    ...    ...    ...
# 32643      False  False  False       False  False  False  False  False
# 32644      False  False  False       False  False  False  False  False
# 32645      False  False  False       False  False  False  False  False
# 32646      False  False  False       False  False  False  False  False
# 32647      False  False  False       False  False  False  False  False
#
# [32648 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  str
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  str
# dtypes: float64(4), str(4)
# memory usage: 2.0 MB

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
owner_dict = {'First Owner': 1, 'Second Owner': 2, 'Third Owner': 3, 'Fourth Owner Or More': 4}

# %%
df['owner']=df['owner'].map(owner_dict)

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
#        owner   age  power          brand
# ...

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  int64
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  str
# dtypes: float64(4), int64(1), str(3)
# memory usage: 2.0 MB

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
#        owner   age  power          brand
# ...

# %%
brand_dict = {
     'TVS':1, 'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
           'Honda':5,            'Hero':6,           'Bajaj':7,          'Suzuki':8,
         'Benelli':9,             'KTM':10,        'Mahindra':11,        'Kawasaki':12,
          'Ducati':13,         'Hyosung':14, 'Harley-Davidson':15,            'Jawa':16,
             'BMW':17,          'Indian':18,         'Rajdoot':19,             'LML':20,
           'Yezdi':21,              'MV':22,           'Ideal':23}

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
#        owner   age  power          brand
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  int64
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  str
# dtypes: float64(4), int64(1), str(3)
# memory usage: 2.0 MB

# %%
obj_val =df.select_dtypes(include='O')
# Out:
# C:\Users\SHRADDHA\AppData\Local\Temp\ipykernel_43180\2170337667.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_val =df.select_dtypes(include='O')

# %%
obj_val
# Out:
#                                   bike_name       city          brand
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad            TVS
# 1               Royal Enfield Classic 350cc      Delhi  Royal Enfield
# 2                      Triumph Daytona 675R      Delhi        Triumph
# 3                      TVS Apache RTR 180cc  Bangalore            TVS
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore         Yamaha
# ...                                     ...        ...            ...
# 32643                Hero Passion Pro 100cc      Delhi           Hero
# 32644                  TVS Apache RTR 180cc     Karnal            TVS
# 32645              Bajaj Avenger Street 220      Delhi          Bajaj
# 32646             Hero Super Splendor 125cc     Jaipur           Hero
# 32647                    Bajaj Pulsar 150cc       Pune          Bajaj
#
# [32648 rows x 3 columns]

# %%
num_val =df.select_dtypes(exclude='O')

# %%
num_val
# Out:
#           price  kms_driven  owner   age  power
# 0       35000.0     17654.0      1   3.0  110.0
# 1      119900.0     11000.0      1   4.0  350.0
# 2      600000.0       110.0      1   8.0  675.0
# 3       65000.0     16329.0      1   4.0  180.0
# 4       80000.0     10000.0      1   3.0  150.0
# ...         ...         ...    ...   ...    ...
# 32643   39000.0     22000.0      1   4.0  100.0
# 32644   30000.0      6639.0      1   9.0  180.0
# 32645   60000.0     20373.0      1   6.0  220.0
# 32646   15600.0     84186.0      1  16.0  125.0
# 32647   22000.0     60857.0      1  13.0  150.0
#
# [32648 rows x 5 columns]

# %%
complete_Data =pd.concat([obj_val, num_val], axis=1)

# %%
complete_Data
# Out:
#                                   bike_name       city          brand  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad            TVS
# 1               Royal Enfield Classic 350cc      Delhi  Royal Enfield
# 2                      Triumph Daytona 675R      Delhi        Triumph
# 3                      TVS Apache RTR 180cc  Bangalore            TVS
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore         Yamaha
# ...                                     ...        ...            ...
# 32643                Hero Passion Pro 100cc      Delhi           Hero
# 32644                  TVS Apache RTR 180cc     Karnal            TVS
# 32645              Bajaj Avenger Street 220      Delhi          Bajaj
# 32646             Hero Super Splendor 125cc     Jaipur           Hero
# 32647                    Bajaj Pulsar 150cc       Pune          Bajaj
#
#           price  kms_driven  owner   age  power
# 0       35000.0     17654.0      1   3.0  110.0
# ...

# %%
RoyalEnfield_brand =df[df['brand']=='Royal Enfield']

# %%
RoyalEnfield_brand['owner'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
RoyalEnfield_first_owner = df[(df['brand']=='Royal Enfield')]

# %%
RoyalEnfield_first_owner[RoyalEnfield_first_owner['age']<5]
# Out:
#                                 bike_name     price        city  kms_driven  \
# 1             Royal Enfield Classic 350cc  119900.0       Delhi     11000.0
# 8       Royal Enfield Thunderbird X 350cc  145000.0   Bangalore      9190.0
# 38      Royal Enfield Thunderbird X 500cc  190500.0  Samastipur      4550.0
# 62     Royal Enfield Bullet Electra 350cc  107100.0       Delhi     15438.0
# 73      Royal Enfield Thunderbird X 350cc  150000.0   Bangalore     15000.0
# ...                                   ...       ...         ...         ...
# 32348  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
# 32367  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
# 32443  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
# 32481  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
# 32614  Royal Enfield Bullet Electra 350cc  105000.0       Delhi     20000.0
#
#        owner  age  power          brand
# ...

# %%
df['kms_driven'].unique()
# Out:
# array([17654., 11000.,   110., ..., 48587.,  3430.,  7127.], shape=(3722,))

# %%
RoyalEnfield_first_owner[RoyalEnfield_first_owner['kms_driven']<500]
# Out:
#                                              bike_name     price       city  \
# 850               Royal Enfield Himalayan 410cc Fi ABS  180000.0   Guwahati
# 974                         Royal Enfield Bullet 350cc   99999.0  Balrampur
# 1796              Royal Enfield Himalayan 410cc Fi ABS  166000.0   Guwahati
# 1883              Royal Enfield Himalayan 410cc Fi ABS  166000.0   Guwahati
# 2740                   Royal Enfield Thunderbird 350cc  147000.0  Bangalore
# 3523                Royal Enfield Bullet Electra 350cc  112200.0  Bangalore
# 3675                   Royal Enfield Thunderbird 350cc  147000.0  Bangalore
# 6090  Royal Enfield Bullet Electra Twinspark 350CC ABS  127000.0     Mumbai
# 7213                   Royal Enfield Thunderbird 500cc  154000.0    Udaipur
# 7694            Royal Enfield Classic Chrome 500cc ABS  215000.0      Delhi
# 7706            Royal Enfield Classic Chrome 500cc ABS  215000.0      Delhi
# ...

# %%
RoyalEnfield_second_owner = df[(df['brand']=='Royal Enfield')]

# %%
RoyalEnfield_second_owner[RoyalEnfield_second_owner['age']<4]
# Out:
#                                   bike_name     price         city  \
# 8         Royal Enfield Thunderbird X 350cc  145000.0    Bangalore
# 38        Royal Enfield Thunderbird X 500cc  190500.0   Samastipur
# 62       Royal Enfield Bullet Electra 350cc  107100.0        Delhi
# 73        Royal Enfield Thunderbird X 350cc  150000.0    Bangalore
# 81          Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai
# ...                                     ...       ...          ...
# 8597            Royal Enfield Electra 350cc   90000.0       Mumbai
# 8741             Royal Enfield Bullet 500cc  135000.0       Rohtak
# 8836  Royal Enfield Thunderbird X 350cc ABS  170200.0       Mumbai
# 9185  Royal Enfield Classic 500cc Dual Disc  163500.0     Azamgarh
# 9308  Royal Enfield Classic 500cc Dual Disc  163500.0     Azamgarh
#
#       kms_driven  owner  age  power          brand
# 8         9190.0      1  3.0  350.0  Royal Enfield
# 38        4550.0      1  2.0  500.0  Royal Enfield
# ...

# %%
#df['owner'] = df['owner'].map(owner_dict)

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
RoyalEnfield_brand=df[df['brand']=='Royal Enfield']

# %%
RoyalEnfield_under_2=RoyalEnfield_brand[RoyalEnfield_brand['age']<=2]

# %%
RoyalEnfield_under_2[RoyalEnfield_under_2['kms_driven']<=15000]
# Out:
#                                    bike_name     price         city  \
# 38         Royal Enfield Thunderbird X 500cc  190500.0   Samastipur
# 81           Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai
# 139     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 157     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 194              Royal Enfield Electra 350cc  145000.0    Bangalore
# ...                                      ...       ...          ...
# 7694  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 7706  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 8139   Royal Enfield Thunderbird X 350cc ABS  169000.0    Bangalore
# 8192     Royal Enfield Thunderbird 350cc ABS  145000.0    Ghaziabad
# 8836   Royal Enfield Thunderbird X 350cc ABS  170200.0       Mumbai
#
#       kms_driven  owner  age  power          brand
# 38        4550.0      1  2.0  500.0  Royal Enfield
# ...

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df[(df['brand']=='Royal Enfield')&(df['age']<=2)&(df['kms_driven']<=15000)]
# Out:
#                                    bike_name     price         city  \
# 38         Royal Enfield Thunderbird X 500cc  190500.0   Samastipur
# 81           Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai
# 139     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 157     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 194              Royal Enfield Electra 350cc  145000.0    Bangalore
# ...                                      ...       ...          ...
# 7694  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 7706  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 8139   Royal Enfield Thunderbird X 350cc ABS  169000.0    Bangalore
# 8192     Royal Enfield Thunderbird 350cc ABS  145000.0    Ghaziabad
# 8836   Royal Enfield Thunderbird X 350cc ABS  170200.0       Mumbai
#
#       kms_driven  owner  age  power          brand
# 38        4550.0      1  2.0  500.0  Royal Enfield
# ...

# %%
df.query("brand=='Royal Enfield'and age<=2")
# Out:
#                                    bike_name     price         city  \
# 38         Royal Enfield Thunderbird X 500cc  190500.0   Samastipur
# 81           Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai
# 139     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 157     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 194              Royal Enfield Electra 350cc  145000.0    Bangalore
# ...                                      ...       ...          ...
# 7694  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 7706  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 8139   Royal Enfield Thunderbird X 350cc ABS  169000.0    Bangalore
# 8192     Royal Enfield Thunderbird 350cc ABS  145000.0    Ghaziabad
# 8836   Royal Enfield Thunderbird X 350cc ABS  170200.0       Mumbai
#
#       kms_driven  owner  age  power          brand
# 38        4550.0      1  2.0  500.0  Royal Enfield
# ...

# %%
df.drop(['bike_name','city'],axis=1)
# Out:
#           price  kms_driven  owner   age  power          brand
# 0       35000.0     17654.0      1   3.0  110.0            TVS
# 1      119900.0     11000.0      1   4.0  350.0  Royal Enfield
# 2      600000.0       110.0      1   8.0  675.0        Triumph
# 3       65000.0     16329.0      1   4.0  180.0            TVS
# 4       80000.0     10000.0      1   3.0  150.0         Yamaha
# ...         ...         ...    ...   ...    ...            ...
# 32643   39000.0     22000.0      1   4.0  100.0           Hero
# 32644   30000.0      6639.0      1   9.0  180.0            TVS
# 32645   60000.0     20373.0      1   6.0  220.0          Bajaj
# 32646   15600.0     84186.0      1  16.0  125.0           Hero
# 32647   22000.0     60857.0      1  13.0  150.0          Bajaj
#
# [32648 rows x 6 columns]

# %%
x=df.drop(['price'],axis=1)

# %%
##y =mx+c
y=df['price']

# %%
y
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
x
# Out:
#                                   bike_name       city  kms_driven  owner  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad     17654.0      1
# 1               Royal Enfield Classic 350cc      Delhi     11000.0      1
# 2                      Triumph Daytona 675R      Delhi       110.0      1
# 3                      TVS Apache RTR 180cc  Bangalore     16329.0      1
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore     10000.0      1
# ...                                     ...        ...         ...    ...
# 32643                Hero Passion Pro 100cc      Delhi     22000.0      1
# 32644                  TVS Apache RTR 180cc     Karnal      6639.0      1
# 32645              Bajaj Avenger Street 220      Delhi     20373.0      1
# 32646             Hero Super Splendor 125cc     Jaipur     84186.0      1
# 32647                    Bajaj Pulsar 150cc       Pune     60857.0      1
#
#         age  power          brand
# 0       3.0  110.0            TVS
# ...

# %%
#from sklearn.model_selection import train_test_split

# %%
# data ko save ka liya 
df.to_csv("clear_bike_data.csv")

# %%
print("hello hii kase ho")
# Out:
# hello hii kase ho

# %% [markdown]
# ### conditional statement
# **conditional statement**are used to make decision in program.they exceute different block of code based on condition
# Type of condition Statement in python
# if statement
# if -else statement
# if -elif-else statement
# Nested if statement

# %%
3+5
# Out:
# 8

# %%
num = input("enter your  number")
print(type(num))
# Out:
# <class 'str'>

# %%
num = int(input("enter your  number"))
print(type(num))
# Out:
# <class 'int'>

# %%
bal= 5000
#withdraw = int(input("Enter your amount"))
withdraw = 2000
if withdraw<= bal:
    print("aapke account mai paise h")
else:
    print("aapka account mai paise nhi h ")
# Out:
# aapke account mai paise h

# %%
#user sai input
bal= 5000
withdraw = int(input("Enter your amount"))
#withdraw = 2000
if withdraw<= bal:
    print("aapke account mai paise h")
else:
    print("aapka account mai paise nhi h ")
# Out:
# aapka account mai paise nhi h

# %%
###student fail and pass
max =36
if max<=33:
    print("fail")
else:
    print("pass")
# Out:
# pass

# %%
###signal 1
signal = "red"
if signal == "red":
    print("stop")
elif signal == "yellow":
    print("ready")
else:
    print("go")
# Out:
# stop

# %%
###vote1
min_age = 18

if min_age <= 17:
    print("not adult")
else:
    print("adult")
# Out:
# adult

# %%
##blinkite offer
order_item = 199
if order_item <=200:
    print("add more item")
else:
    print("free item")
# Out:
# add more item

# %%
min_marks=100
if min_marks <=97:
    print("A++")
elif min_marks <=60:
    print("B+")
else:
    print("fail")
# Out:
# fail

# %% [markdown]
# nested if condition

# %%
#if cond:
# if cond:
#     ###code
# else:
#     ##code
# else:
#     ###code

# %%
attendance = 50
marks =33
if  attendence >=75:
    if marks >= 36:
        print("pass")
    else:
        print("fail in exam")
else:
    print("low attendance")

# %%
bal_pin = int(input("enter your pin"))
balance = int(input("enter your balance"))
if bal_pin == 4567:
    if balance >=6000:
        print("Transcation successful")
    else:
        print("wrong pin")
else:
    print("Transcation Fail")4567
    5000
# Out:
# wrong pin

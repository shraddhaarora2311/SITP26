# %% [markdown]
# ### Class in python
# Class ek user-defined structure hai jo:
#
# variables (data)
# methods/functions
#
# ko ek jagah organize karti hai.
#
#
# **Pillars of OOP in Python**
#
# ### Python mai OOP (Object Oriented Programming) ke 4 main pillars hote hain:
#
# Encapsulation
# Inheritance
# Polymorphism
# Abstraction
#
#
# 1. **Encapsulation**
#
# Data aur methods ko ek class ke andar wrap karna Encapsulation kehlata hai.
#
# Simple words:
# Data ko secure rakhna
#
#
# 2. **Inheritance**
#
# Ek class dusri class ke properties aur methods ko use kare toh usse Inheritance bolte hain.
#
#
# 3. **Polymorphism**
#
# Ek hi function ka alag-alag behavior hona Polymorphism kehlata hai.
#
# 4. **Abstraction**
#
# Important details dikhana aur unnecessary details hide karna Abstraction kehlata hai.

# %% [markdown]
# ### Definition of Class in Python
#
# A class is a blueprint or template used to create objects.
# It combines data (variables) and functions (methods) into a single unit.
#
# OR
#
# A class is a user-defined data type in Python that helps in implementing Object-Oriented Programming (OOP) concepts.
# ### Python Class Notes
# | Topic                 | Description                                                        |
# | --------------------- | ------------------------------------------------------------------ |
# | **Class**             | A class is a blueprint used to create objects.                     |
# | **Object**            | An object is an instance of a class.                               |
# | **OOP**               | OOP stands for Object-Oriented Programming.                        |
# | **Syntax**            | `class ClassName:`                                                 |
# | **Constructor**       | `__init__()` is a special method used to initialize object values. |
# | **self Keyword**      | `self` refers to the current object of the class.                  |
# | **Method**            | A function inside a class is called a method.                      |
# | **Attribute**         | Variables inside a class are called attributes.                    |
# | **Instance Variable** | Variables created using `self` are instance variables.             |
# | **Object Creation**   | `obj = ClassName()`                                                |
# | **Advantages**        | Code reusability, better structure, easy maintenance.              |
#
# #### Four Pillars of OOP
# | Pillar            | Definition                                                   | Example              |
# | ----------------- | ------------------------------------------------------------ | -------------------- |
# | **Encapsulation** | Wrapping data and methods into one unit.                     | Class and object     |
# | **Inheritance**   | One class acquires properties of another class.              | Parent → Child class |
# | **Polymorphism**  | Same function behaves differently in different situations.   | Method Overriding    |
# | **Abstraction**   | Hiding internal details and showing only important features. | Abstract class       |

# %%
class Classname:
    pass

# %%
class LastName:
    pass
#from fastapi import FastAPI
# class ko kase define karta hai

# %%
class Student:
    pass
#class is a keyword and student is a class

# %%
class Student:
    name = "Shraddha"##class varibles
    pass

# %%
class Student:
    name ="Shraddha"

st=Student()##object create 1 class ka liya multiple object create kar sakhta hai and st is a object 


#Student = class
#st = object
#name = attributes(class varibles)

# %%
class Student:
    name="Shraddha"
    classes ="CSE"
    roll_number="23EMCS47"

st =Student()
st.name
st.classes
st.roll_number
# Out:
# '23EMCS47'

# %%
class College:
    name="Shraddha"
    classes ="CSE"
    roll_number="23EMCS47"



riya =College()
Akk =College()
riya.classes
Akk.roll_number
# Out:
# '23EMCS47'

# %%
class College:
    College_name ="GWECA"
    College_address ="Ajmer"
    College_sp =47


riya =College()
ritik =College()
happy =College()

# %%
#happy.name

# %%
class College:
    college_name = "Arya Main Campus"
    def display(self):#argument pass karan tha varena error show hogi
        pass

clg =College()

# %%
clg.display()

# %%
class Collage:
    collage_name ="GWECA"
    collage_address ="Ajmer"
    collagesp =47
    def show(self):
        print(self.collage_name)
        print(self.collage_address)
        print(self.collagesp)
        
clg =Collage()

# %%
clg.show()
# Out:
# GWECA
# Ajmer
# 47

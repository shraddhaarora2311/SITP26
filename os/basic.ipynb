# %%
import os

# %%
os.getcwd()#current working directory
# Out:
# 'c:\\data science\\os'

# %%
path = r'c:\\data science\\os'
os.listdir(path)
# Out:
# ['basic.ipynb', 'hello']

# %%
##os.mkdir("hello")

# %%
os.getcwd()
# Out:
# 'c:\\data science\\os'

# %%
os.getcwd()
# Out:
# 'c:\\data science\\os'

# %%
os.mkdir("student\\data\\reports")#student name ki dir banai h ose ka bade mai
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 os.mkdir("student\\data\\reports")#student name ki dir banai h ose ka bade mai
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'student\\data\\reports'

# %%
os.listdir(os.gatcwd())

# %%
os.rename("student",colllage)

# %%
##os.chdir(r"C:\data science\flask")

# %%
##os.listdir(os.getcwd())
# Out:
# []

# %%
path =r"C:\data science\python"### break the two parts half part is another then next aother half part is another
path1= r"C:\data science"
path2= r"python"
complete_path=os.path.join(path1,path2)
print(complete_path)
print("final output:-",os.listdir(complete_path))
# Out:
# C:\data science\python
# final output:- ['.venv', 'Assignment.ipynb', 'assignment.py', 'basic.py', 'classes.ipynb', 'encapsulation.ipynb', 'forloop.ipynb', 'function.ipynb', 'hiii.ipynb', 'inhertance.ipynb']

# %%
os.path.isdir(r"C:\data science\python")
# Out:
# True

# %%
os.path.isfile(r"C:\data science\python")
# Out:
# False

# %%
os.path.exists(r"C:\data science\python")
# Out:
# True

# %%
os.path.getsize(r"C:\data science\python")
# Out:
# 4096

# %% [markdown]
# | Function           | Work                          | Example                       |
# | ------------------ | ----------------------------- | ----------------------------- |
# | `os.getcwd()`      | Get current working directory | `os.getcwd()`                 |
# | `os.chdir(path)`   | Change current directory      | `os.chdir("D:/Python")`       |
# | `os.listdir()`     | Show all files and folders    | `os.listdir()`                |
# | `os.mkdir()`       | Create one folder             | `os.mkdir("Student")`         |
# | `os.makedirs()`    | Create multiple folders       | `os.makedirs("Data/Student")` |
# | `os.rmdir()`       | Delete empty folder           | `os.rmdir("Student")`         |
# | `os.removedirs()`  | Delete nested empty folders   | `os.removedirs("A/B/C")`      |
# | `os.remove()`      | Delete file                   | `os.remove("data.txt")`       |
# | `os.rename()`      | Rename file/folder            | `os.rename("old","new")`      |
# | `os.path.exists()` | Check file/folder exists      | `os.path.exists("Data")`      |
# | `os.path.isfile()` | Check file exists             | `os.path.isfile("a.txt")`     |
# | `os.path.isdir()`  | Check folder exists           | `os.path.isdir("Student")`    |
# | `os.path.join()`   | Join file paths               | `os.path.join("A","B")`       |
